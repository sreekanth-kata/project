# %%
from PIL import Image
import scipy.misc
import os

from __future__ import print_function

import scipy.io as spio
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import keras
from keras.models import model_from_json

patch_size = 50

def evaluateScore(x_): 
    # modify x_test y_test(GT) by sliding a window in test image to obtain x_test
    x_test = np.zeros((1,patch_size, patch_size, 1), dtype=np.float)
    x_test[0,:,:,0] = x_;
    y_test = np.zeros((1,2), dtype=np.float)
    
    # evaluate loaded model on test data
    scores = loaded_model.evaluate(x_test, y_test, verbose=0)  
    return scores[0]
# Out:
# Using TensorFlow backend.

# %%
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
loaded_model.compile(loss='binary_crossentropy', 
                     optimizer='rmsprop', 
                     metrics=['accuracy'])

#load one test image
image = Image.open("test_img1.png")#.convert('L')
#image.show()

#1.create a RGB image (same size of original image) to show the visualization 
#2.make the test_box GREEN, if the test_box is detected positive, else RED

RED = Image.new('RGBA', (patch_size, patch_size), (255,0,0,128))
GREEN = Image.new('RGBA', (patch_size, patch_size), (0,255,0,128))
for i in range(0, image.size[0], patch_size):
    for j in range(0, image.size[1], patch_size):            
        box = image.crop((i, j, i + patch_size, j + patch_size))                
        x = i
        y = j
        w = patch_size
        h = patch_size
        
        data = np.asarray(box)  
        numpy_sum = np.sum(np.sum(data, axis=0), axis=0)
        print('row:', i, ' col:', j, '\t', 'numpy_sum:',numpy_sum)
        
        # evaluate this patch
        score = evaluateScore(data)        
        print('Evaluate score:=', score)
       
        ## save masked image
        name = ('test/ImgWithPatch_i{}_j{}.png').format(i, j)
        print(name, '\n')
        result = image.copy();
        result = result.convert('RGBA')
        break
#         if score < 4:
#             result.paste(RED, (i, j, i + patch_size, j + patch_size)) 
#         else:
#             result.paste(GREEN, (i, j, i + patch_size, j + patch_size))
#         result.save(name, "PNG")
print(max(score, key=score.get))
# Out:
# Loaded model from disk
# row: 0  col: 0 	 numpy_sum: 1418
# Evaluate score:= 3.48806738853
# test/ImgWithPatch_i0_j0.png
#
# row: 0  col: 50 	 numpy_sum: 1976
# Evaluate score:= 2.19959449768
# test/ImgWithPatch_i0_j50.png
#
# row: 0  col: 100 	 numpy_sum: 1915
# Evaluate score:= 2.20618510246
# test/ImgWithPatch_i0_j100.png
#
# row: 0  col: 150 	 numpy_sum: 1282
# Evaluate score:= 0.808582186699
# test/ImgWithPatch_i0_j150.png
#
# row: 0  col: 200 	 numpy_sum: 1515
# Evaluate score:= 0.791707575321
# test/ImgWithPatch_i0_j200.png
#
# row: 0  col: 250 	 numpy_sum: 1700
# Evaluate score:= 2.50956916809
# test/ImgWithPatch_i0_j250.png
#
# row: 0  col: 300 	 numpy_sum: 1700
# Evaluate score:= 2.50956916809
# test/ImgWithPatch_i0_j300.png
#
# row: 0  col: 350 	 numpy_sum: 1700
# Evaluate score:= 2.50956916809
# test/ImgWithPatch_i0_j350.png
#
# row: 0  col: 400 	 numpy_sum: 1671
# Evaluate score:= 3.14464187622
# test/ImgWithPatch_i0_j400.png
#
# row: 0  col: 450 	 numpy_sum: 1641
# Evaluate score:= 2.86242580414
# test/ImgWithPatch_i0_j450.png
#
# row: 0  col: 500 	 numpy_sum: 1662
# Evaluate score:= 1.92063236237
# test/ImgWithPatch_i0_j500.png
#
# row: 0  col: 550 	 numpy_sum: 1642
# Evaluate score:= 1.90188443661
# test/ImgWithPatch_i0_j550.png
#
# row: 0  col: 600 	 numpy_sum: 1623
# Evaluate score:= 2.76256275177
# test/ImgWithPatch_i0_j600.png
#
# row: 0  col: 650 	 numpy_sum: 1608
# Evaluate score:= 0.702761173248
# test/ImgWithPatch_i0_j650.png
#
# row: 0  col: 700 	 numpy_sum: 1603
# Evaluate score:= 0.693655848503
# test/ImgWithPatch_i0_j700.png
#
# row: 0  col: 750 	 numpy_sum: 1592
# Evaluate score:= 0.701925635338
# test/ImgWithPatch_i0_j750.png
#
# row: 0  col: 800 	 numpy_sum: 1600
# Evaluate score:= 0.694425106049
# test/ImgWithPatch_i0_j800.png
#
# row: 0  col: 850 	 numpy_sum: 1550
# Evaluate score:= 1.0582306385
# test/ImgWithPatch_i0_j850.png
#
# row: 0  col: 900 	 numpy_sum: 1600
# Evaluate score:= 0.694425106049
# test/ImgWithPatch_i0_j900.png
#
# row: 0  col: 950 	 numpy_sum: 1600
# Evaluate score:= 0.694425106049
# test/ImgWithPatch_i0_j950.png
#
# row: 0  col: 1000 	 numpy_sum: 1589
# Evaluate score:= 0.773569464684
# test/ImgWithPatch_i0_j1000.png
#
# row: 0  col: 1050 	 numpy_sum: 1551
# Evaluate score:= 1.94258058071
# test/ImgWithPatch_i0_j1050.png
#
# row: 0  col: 1100 	 numpy_sum: 1545
# Evaluate score:= 1.36547279358
# test/ImgWithPatch_i0_j1100.png
#
# row: 0  col: 1150 	 numpy_sum: 1460
# Evaluate score:= 0.733992576599
# test/ImgWithPatch_i0_j1150.png
#
# row: 0  col: 1200 	 numpy_sum: 1526
# Evaluate score:= 0.946433186531
# test/ImgWithPatch_i0_j1200.png
#
# row: 0  col: 1250 	 numpy_sum: 1515
# Evaluate score:= 1.14970445633
# test/ImgWithPatch_i0_j1250.png
#
# row: 0  col: 1300 	 numpy_sum: 1504
# Evaluate score:= 0.693252980709
# test/ImgWithPatch_i0_j1300.png
#
# row: 0  col: 1350 	 numpy_sum: 1479
# Evaluate score:= 0.862062335014
# test/ImgWithPatch_i0_j1350.png
#
# row: 0  col: 1400 	 numpy_sum: 1496
# Evaluate score:= 0.821394324303
# test/ImgWithPatch_i0_j1400.png
#
# row: 0  col: 1450 	 numpy_sum: 1498
# Evaluate score:= 0.695956408978
# test/ImgWithPatch_i0_j1450.png
#
# row: 0  col: 1500 	 numpy_sum: 1490
# Evaluate score:= 1.10297703743
# test/ImgWithPatch_i0_j1500.png
#
# row: 0  col: 1550 	 numpy_sum: 1470
# Evaluate score:= 1.19461286068
# test/ImgWithPatch_i0_j1550.png
#
# row: 0  col: 1600 	 numpy_sum: 1452
# Evaluate score:= 0.78705316782
# test/ImgWithPatch_i0_j1600.png
#
# row: 0  col: 1650 	 numpy_sum: 1082
# Evaluate score:= 0.698675394058
# test/ImgWithPatch_i0_j1650.png
#
# row: 0  col: 1700 	 numpy_sum: 1432
# Evaluate score:= 1.49616718292
# test/ImgWithPatch_i0_j1700.png
#
# row: 0  col: 1750 	 numpy_sum: 1436
# Evaluate score:= 1.99779582024
# test/ImgWithPatch_i0_j1750.png
#
# row: 0  col: 1800 	 numpy_sum: 1401
# Evaluate score:= 3.52425789833
# test/ImgWithPatch_i0_j1800.png
#
# row: 0  col: 1850 	 numpy_sum: 1397
# Evaluate score:= 3.97540354729
# test/ImgWithPatch_i0_j1850.png
#
# row: 0  col: 1900 	 numpy_sum: 1366
# Evaluate score:= 3.36897158623
# test/ImgWithPatch_i0_j1900.png
#
# row: 0  col: 1950 	 numpy_sum: 1377
# Evaluate score:= 2.86255288124
# test/ImgWithPatch_i0_j1950.png
#
# row: 0  col: 2000 	 numpy_sum: 1356
# Evaluate score:= 0.697786450386
# test/ImgWithPatch_i0_j2000.png
#
# row: 0  col: 2050 	 numpy_sum: 1337
# Evaluate score:= 1.09885299206
# test/ImgWithPatch_i0_j2050.png
#
# row: 0  col: 2100 	 numpy_sum: 1328
# Evaluate score:= 1.97320413589
# test/ImgWithPatch_i0_j2100.png
#
# row: 0  col: 2150 	 numpy_sum: 1333
# Evaluate score:= 1.92074644566
# test/ImgWithPatch_i0_j2150.png
#
# row: 0  col: 2200 	 numpy_sum: 1338
# Evaluate score:= 1.48443365097
# test/ImgWithPatch_i0_j2200.png
#
# row: 0  col: 2250 	 numpy_sum: 1332
# Evaluate score:= 1.37946009636
# test/ImgWithPatch_i0_j2250.png
#
# row: 0  col: 2300 	 numpy_sum: 1300
# Evaluate score:= 5.43050003052
# test/ImgWithPatch_i0_j2300.png
#
# row: 0  col: 2350 	 numpy_sum: 1298
# Evaluate score:= 5.50038003922
# test/ImgWithPatch_i0_j2350.png
#
# row: 0  col: 2400 	 numpy_sum: 1289
# Evaluate score:= 5.24783754349
# test/ImgWithPatch_i0_j2400.png
#
# row: 0  col: 2450 	 numpy_sum: 1286
# Evaluate score:= 4.66387414932
# test/ImgWithPatch_i0_j2450.png
#
# row: 0  col: 2500 	 numpy_sum: 1250
# Evaluate score:= 3.05286359787
# test/ImgWithPatch_i0_j2500.png
#
# row: 0  col: 2550 	 numpy_sum: 1247
# Evaluate score:= 3.01207470894
# test/ImgWithPatch_i0_j2550.png
#
# row: 0  col: 2600 	 numpy_sum: 1226
# Evaluate score:= 4.08275270462
# test/ImgWithPatch_i0_j2600.png
#
# row: 0  col: 2650 	 numpy_sum: 1226
# Evaluate score:= 3.38856911659
# test/ImgWithPatch_i0_j2650.png
#
# row: 0  col: 2700 	 numpy_sum: 1214
# Evaluate score:= 3.05535769463
# test/ImgWithPatch_i0_j2700.png
#
# row: 0  col: 2750 	 numpy_sum: 1200
# Evaluate score:= 3.8627614975
# test/ImgWithPatch_i0_j2750.png
#
# row: 0  col: 2800 	 numpy_sum: 1196
# Evaluate score:= 3.21961236
# test/ImgWithPatch_i0_j2800.png
#
# row: 0  col: 2850 	 numpy_sum: 1196
# Evaluate score:= 4.13366365433
# test/ImgWithPatch_i0_j2850.png
#
# row: 0  col: 2900 	 numpy_sum: 1186
# Evaluate score:= 4.13973283768
# test/ImgWithPatch_i0_j2900.png
#
# row: 0  col: 2950 	 numpy_sum: 1163
# Evaluate score:= 4.10613155365
# test/ImgWithPatch_i0_j2950.png
#
# row: 0  col: 3000 	 numpy_sum: 1150
# Evaluate score:= 3.94411873817
# test/ImgWithPatch_i0_j3000.png
#
# row: 0  col: 3050 	 numpy_sum: 1150
# Evaluate score:= 3.94411873817
# test/ImgWithPatch_i0_j3050.png
#
# row: 0  col: 3100 	 numpy_sum: 1149
# Evaluate score:= 4.21267747879
# test/ImgWithPatch_i0_j3100.png
#
# row: 0  col: 3150 	 numpy_sum: 1238
# Evaluate score:= 4.73738193512
# test/ImgWithPatch_i0_j3150.png
#
# row: 0  col: 3200 	 numpy_sum: 912
# Evaluate score:= 0.695172548294
# test/ImgWithPatch_i0_j3200.png
#
# row: 50  col: 0 	 numpy_sum: 1802
# Evaluate score:= 1.02333676815
# test/ImgWithPatch_i50_j0.png
#
# row: 50  col: 50 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j50.png
#
# row: 50  col: 100 	 numpy_sum: 2489
# Evaluate score:= 0.715456604958
# test/ImgWithPatch_i50_j100.png
#
# row: 50  col: 150 	 numpy_sum: 1646
# Evaluate score:= 1.2407630682
# test/ImgWithPatch_i50_j150.png
#
# row: 50  col: 200 	 numpy_sum: 2279
# Evaluate score:= 1.22544062138
# test/ImgWithPatch_i50_j200.png
#
# row: 50  col: 250 	 numpy_sum: 2498
# Evaluate score:= 0.789784550667
# test/ImgWithPatch_i50_j250.png
#
# row: 50  col: 300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j300.png
#
# row: 50  col: 350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j350.png
#
# row: 50  col: 400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j400.png
#
# row: 50  col: 450 	 numpy_sum: 2488
# Evaluate score:= 1.44212758541
# test/ImgWithPatch_i50_j450.png
#
# row: 50  col: 500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j500.png
#
# row: 50  col: 550 	 numpy_sum: 2494
# Evaluate score:= 0.784932732582
# test/ImgWithPatch_i50_j550.png
#
# row: 50  col: 600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j600.png
#
# row: 50  col: 650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j650.png
#
# row: 50  col: 700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j700.png
#
# row: 50  col: 750 	 numpy_sum: 2494
# Evaluate score:= 0.693219184875
# test/ImgWithPatch_i50_j750.png
#
# row: 50  col: 800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j800.png
#
# row: 50  col: 850 	 numpy_sum: 2494
# Evaluate score:= 0.8546179533
# test/ImgWithPatch_i50_j850.png
#
# row: 50  col: 900 	 numpy_sum: 2493
# Evaluate score:= 0.733612000942
# test/ImgWithPatch_i50_j900.png
#
# row: 50  col: 950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j950.png
#
# row: 50  col: 1000 	 numpy_sum: 2490
# Evaluate score:= 0.713096559048
# test/ImgWithPatch_i50_j1000.png
# row: 50  col: 1050 	 numpy_sum: 2490
# Evaluate score:= 0.845904946327
# test/ImgWithPatch_i50_j1050.png
#
# row: 50  col: 1100 	 numpy_sum: 2499
# Evaluate score:= 0.734240949154
# test/ImgWithPatch_i50_j1100.png
#
# row: 50  col: 1150 	 numpy_sum: 2371
# Evaluate score:= 1.34574091434
# test/ImgWithPatch_i50_j1150.png
#
# row: 50  col: 1200 	 numpy_sum: 2494
# Evaluate score:= 1.08367323875
# test/ImgWithPatch_i50_j1200.png
#
# row: 50  col: 1250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j1250.png
#
# row: 50  col: 1300 	 numpy_sum: 2479
# Evaluate score:= 0.697866261005
# test/ImgWithPatch_i50_j1300.png
#
# row: 50  col: 1350 	 numpy_sum: 2472
# Evaluate score:= 0.730678081512
# test/ImgWithPatch_i50_j1350.png
#
# row: 50  col: 1400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j1400.png
#
# row: 50  col: 1450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j1450.png
#
# row: 50  col: 1500 	 numpy_sum: 2499
# Evaluate score:= 0.709537148476
# test/ImgWithPatch_i50_j1500.png
#
# row: 50  col: 1550 	 numpy_sum: 2494
# Evaluate score:= 0.721876442432
# test/ImgWithPatch_i50_j1550.png
#
# row: 50  col: 1600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j1600.png
#
# row: 50  col: 1650 	 numpy_sum: 1831
# Evaluate score:= 4.03359985352
# test/ImgWithPatch_i50_j1650.png
#
# row: 50  col: 1700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j1700.png
#
# row: 50  col: 1750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j1750.png
#
# row: 50  col: 1800 	 numpy_sum: 2499
# Evaluate score:= 0.706130981445
# test/ImgWithPatch_i50_j1800.png
#
# row: 50  col: 1850 	 numpy_sum: 2496
# Evaluate score:= 0.698301196098
# test/ImgWithPatch_i50_j1850.png
#
# row: 50  col: 1900 	 numpy_sum: 2462
# Evaluate score:= 0.844450175762
# test/ImgWithPatch_i50_j1900.png
#
# row: 50  col: 1950 	 numpy_sum: 2489
# Evaluate score:= 1.06035780907
# test/ImgWithPatch_i50_j1950.png
#
# row: 50  col: 2000 	 numpy_sum: 2491
# Evaluate score:= 0.823614239693
# test/ImgWithPatch_i50_j2000.png
#
# row: 50  col: 2050 	 numpy_sum: 2477
# Evaluate score:= 1.0927618742
# test/ImgWithPatch_i50_j2050.png
#
# row: 50  col: 2100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2100.png
#
# row: 50  col: 2150 	 numpy_sum: 2499
# Evaluate score:= 0.712740421295
# test/ImgWithPatch_i50_j2150.png
#
# row: 50  col: 2200 	 numpy_sum: 2498
# Evaluate score:= 0.752298414707
# test/ImgWithPatch_i50_j2200.png
#
# row: 50  col: 2250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2250.png
#
# row: 50  col: 2300 	 numpy_sum: 2499
# Evaluate score:= 1.05580151081
# test/ImgWithPatch_i50_j2300.png
#
# row: 50  col: 2350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2350.png
#
# row: 50  col: 2400 	 numpy_sum: 2443
# Evaluate score:= 0.878946304321
# test/ImgWithPatch_i50_j2400.png
#
# row: 50  col: 2450 	 numpy_sum: 2489
# Evaluate score:= 0.8444480896
# test/ImgWithPatch_i50_j2450.png
#
# row: 50  col: 2500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2500.png
#
# row: 50  col: 2550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2550.png
#
# row: 50  col: 2600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2600.png
#
# row: 50  col: 2650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2650.png
#
# row: 50  col: 2700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2700.png
#
# row: 50  col: 2750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2750.png
#
# row: 50  col: 2800 	 numpy_sum: 2494
# Evaluate score:= 0.76942640543
# test/ImgWithPatch_i50_j2800.png
#
# row: 50  col: 2850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2850.png
#
# row: 50  col: 2900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2900.png
#
# row: 50  col: 2950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j2950.png
#
# row: 50  col: 3000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j3000.png
#
# row: 50  col: 3050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j3050.png
#
# row: 50  col: 3100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j3100.png
#
# row: 50  col: 3150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i50_j3150.png
#
# row: 50  col: 3200 	 numpy_sum: 1450
# Evaluate score:= 2.70778274536
# test/ImgWithPatch_i50_j3200.png
#
# row: 100  col: 0 	 numpy_sum: 1809
# Evaluate score:= 1.52547419071
# test/ImgWithPatch_i100_j0.png
#
# row: 100  col: 50 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j50.png
#
# row: 100  col: 100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j100.png
#
# row: 100  col: 150 	 numpy_sum: 1973
# Evaluate score:= 0.925028920174
# test/ImgWithPatch_i100_j150.png
#
# row: 100  col: 200 	 numpy_sum: 2286
# Evaluate score:= 0.694408297539
# test/ImgWithPatch_i100_j200.png
#
# row: 100  col: 250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j250.png
#
# row: 100  col: 300 	 numpy_sum: 2499
# Evaluate score:= 0.700675487518
# test/ImgWithPatch_i100_j300.png
#
# row: 100  col: 350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j350.png
#
# row: 100  col: 400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j400.png
#
# row: 100  col: 450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j450.png
#
# row: 100  col: 500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j500.png
#
# row: 100  col: 550 	 numpy_sum: 2494
# Evaluate score:= 0.743098497391
# test/ImgWithPatch_i100_j550.png
#
# row: 100  col: 600 	 numpy_sum: 2482
# Evaluate score:= 0.694494605064
# test/ImgWithPatch_i100_j600.png
#
# row: 100  col: 650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j650.png
#
# row: 100  col: 700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j700.png
#
# row: 100  col: 750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j750.png
#
# row: 100  col: 800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j800.png
#
# row: 100  col: 850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j850.png
#
# row: 100  col: 900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j900.png
#
# row: 100  col: 950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j950.png
#
# row: 100  col: 1000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j1000.png
#
# row: 100  col: 1050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j1050.png
#
# row: 100  col: 1100 	 numpy_sum: 2493
# Evaluate score:= 0.741457939148
# test/ImgWithPatch_i100_j1100.png
#
# row: 100  col: 1150 	 numpy_sum: 2413
# Evaluate score:= 1.23399686813
# test/ImgWithPatch_i100_j1150.png
#
# row: 100  col: 1200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j1200.png
#
# row: 100  col: 1250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j1250.png
#
# row: 100  col: 1300 	 numpy_sum: 2497
# Evaluate score:= 1.54146742821
# test/ImgWithPatch_i100_j1300.png
#
# row: 100  col: 1350 	 numpy_sum: 2496
# Evaluate score:= 0.961301743984
# test/ImgWithPatch_i100_j1350.png
#
# row: 100  col: 1400 	 numpy_sum: 2497
# Evaluate score:= 0.766554415226
# test/ImgWithPatch_i100_j1400.png
#
# row: 100  col: 1450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j1450.png
#
# row: 100  col: 1500 	 numpy_sum: 2474
# Evaluate score:= 0.780913352966
# test/ImgWithPatch_i100_j1500.png
#
# row: 100  col: 1550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j1550.png
#
# row: 100  col: 1600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j1600.png
#
# row: 100  col: 1650 	 numpy_sum: 2021
# Evaluate score:= 1.58823156357
# test/ImgWithPatch_i100_j1650.png
#
# row: 100  col: 1700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j1700.png
#
# row: 100  col: 1750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j1750.png
#
# row: 100  col: 1800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j1800.png
#
# row: 100  col: 1850 	 numpy_sum: 2484
# Evaluate score:= 0.757211327553
# test/ImgWithPatch_i100_j1850.png
#
# row: 100  col: 1900 	 numpy_sum: 2462
# Evaluate score:= 1.11335194111
# test/ImgWithPatch_i100_j1900.png
#
# row: 100  col: 1950 	 numpy_sum: 2487
# Evaluate score:= 1.00907433033
# test/ImgWithPatch_i100_j1950.png
# row: 100  col: 2000 	 numpy_sum: 2496
# Evaluate score:= 0.699163556099
# test/ImgWithPatch_i100_j2000.png
#
# row: 100  col: 2050 	 numpy_sum: 2495
# Evaluate score:= 1.06471431255
# test/ImgWithPatch_i100_j2050.png
#
# row: 100  col: 2100 	 numpy_sum: 2498
# Evaluate score:= 0.695322334766
# test/ImgWithPatch_i100_j2100.png
#
# row: 100  col: 2150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2150.png
#
# row: 100  col: 2200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2200.png
#
# row: 100  col: 2250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2250.png
#
# row: 100  col: 2300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2300.png
#
# row: 100  col: 2350 	 numpy_sum: 2490
# Evaluate score:= 0.91793268919
# test/ImgWithPatch_i100_j2350.png
#
# row: 100  col: 2400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2400.png
#
# row: 100  col: 2450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2450.png
#
# row: 100  col: 2500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2500.png
#
# row: 100  col: 2550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2550.png
#
# row: 100  col: 2600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2600.png
#
# row: 100  col: 2650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2650.png
#
# row: 100  col: 2700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2700.png
#
# row: 100  col: 2750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2750.png
#
# row: 100  col: 2800 	 numpy_sum: 2496
# Evaluate score:= 0.722312986851
# test/ImgWithPatch_i100_j2800.png
#
# row: 100  col: 2850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2850.png
#
# row: 100  col: 2900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2900.png
#
# row: 100  col: 2950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j2950.png
#
# row: 100  col: 3000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j3000.png
#
# row: 100  col: 3050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j3050.png
#
# row: 100  col: 3100 	 numpy_sum: 2370
# Evaluate score:= 1.23090028763
# test/ImgWithPatch_i100_j3100.png
#
# row: 100  col: 3150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i100_j3150.png
#
# row: 100  col: 3200 	 numpy_sum: 1450
# Evaluate score:= 2.70778274536
# test/ImgWithPatch_i100_j3200.png
#
# row: 150  col: 0 	 numpy_sum: 1819
# Evaluate score:= 0.697533130646
# test/ImgWithPatch_i150_j0.png
#
# row: 150  col: 50 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j50.png
#
# row: 150  col: 100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j100.png
#
# row: 150  col: 150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j150.png
#
# row: 150  col: 200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j200.png
#
# row: 150  col: 250 	 numpy_sum: 2422
# Evaluate score:= 0.815769672394
# test/ImgWithPatch_i150_j250.png
#
# row: 150  col: 300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j300.png
#
# row: 150  col: 350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j350.png
#
# row: 150  col: 400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j400.png
#
# row: 150  col: 450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j450.png
#
# row: 150  col: 500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j500.png
#
# row: 150  col: 550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j550.png
#
# row: 150  col: 600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j600.png
#
# row: 150  col: 650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j650.png
#
# row: 150  col: 700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j700.png
#
# row: 150  col: 750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j750.png
#
# row: 150  col: 800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j800.png
#
# row: 150  col: 850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j850.png
#
# row: 150  col: 900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j900.png
#
# row: 150  col: 950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j950.png
#
# row: 150  col: 1000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1000.png
#
# row: 150  col: 1050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1050.png
#
# row: 150  col: 1100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1100.png
#
# row: 150  col: 1150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1150.png
#
# row: 150  col: 1200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1200.png
#
# row: 150  col: 1250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1250.png
#
# row: 150  col: 1300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1300.png
#
# row: 150  col: 1350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1350.png
#
# row: 150  col: 1400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1400.png
#
# row: 150  col: 1450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1450.png
#
# row: 150  col: 1500 	 numpy_sum: 2462
# Evaluate score:= 0.965082228184
# test/ImgWithPatch_i150_j1500.png
#
# row: 150  col: 1550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1550.png
#
# row: 150  col: 1600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1600.png
#
# row: 150  col: 1650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1650.png
#
# row: 150  col: 1700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1700.png
#
# row: 150  col: 1750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1750.png
#
# row: 150  col: 1800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1800.png
#
# row: 150  col: 1850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1850.png
#
# row: 150  col: 1900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1900.png
#
# row: 150  col: 1950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j1950.png
#
# row: 150  col: 2000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2000.png
#
# row: 150  col: 2050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2050.png
#
# row: 150  col: 2100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2100.png
#
# row: 150  col: 2150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2150.png
#
# row: 150  col: 2200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2200.png
#
# row: 150  col: 2250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2250.png
#
# row: 150  col: 2300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2300.png
#
# row: 150  col: 2350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2350.png
#
# row: 150  col: 2400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2400.png
#
# row: 150  col: 2450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2450.png
#
# row: 150  col: 2500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2500.png
#
# row: 150  col: 2550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2550.png
#
# row: 150  col: 2600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2600.png
#
# row: 150  col: 2650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2650.png
#
# row: 150  col: 2700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2700.png
#
# row: 150  col: 2750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2750.png
#
# row: 150  col: 2800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2800.png
#
# row: 150  col: 2850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2850.png
# row: 150  col: 2900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2900.png
#
# row: 150  col: 2950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j2950.png
#
# row: 150  col: 3000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j3000.png
#
# row: 150  col: 3050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j3050.png
#
# row: 150  col: 3100 	 numpy_sum: 2207
# Evaluate score:= 1.69480931759
# test/ImgWithPatch_i150_j3100.png
#
# row: 150  col: 3150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i150_j3150.png
#
# row: 150  col: 3200 	 numpy_sum: 1450
# Evaluate score:= 2.70778274536
# test/ImgWithPatch_i150_j3200.png
#
# row: 200  col: 0 	 numpy_sum: 1801
# Evaluate score:= 1.19400155544
# test/ImgWithPatch_i200_j0.png
#
# row: 200  col: 50 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j50.png
#
# row: 200  col: 100 	 numpy_sum: 2421
# Evaluate score:= 1.73841452599
# test/ImgWithPatch_i200_j100.png
#
# row: 200  col: 150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j150.png
#
# row: 200  col: 200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j200.png
#
# row: 200  col: 250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j250.png
#
# row: 200  col: 300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j300.png
#
# row: 200  col: 350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j350.png
#
# row: 200  col: 400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j400.png
#
# row: 200  col: 450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j450.png
#
# row: 200  col: 500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j500.png
#
# row: 200  col: 550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j550.png
#
# row: 200  col: 600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j600.png
#
# row: 200  col: 650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j650.png
#
# row: 200  col: 700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j700.png
#
# row: 200  col: 750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j750.png
#
# row: 200  col: 800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j800.png
#
# row: 200  col: 850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j850.png
#
# row: 200  col: 900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j900.png
#
# row: 200  col: 950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j950.png
#
# row: 200  col: 1000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1000.png
#
# row: 200  col: 1050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1050.png
#
# row: 200  col: 1100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1100.png
#
# row: 200  col: 1150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1150.png
#
# row: 200  col: 1200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1200.png
#
# row: 200  col: 1250 	 numpy_sum: 2460
# Evaluate score:= 0.79825425148
# test/ImgWithPatch_i200_j1250.png
#
# row: 200  col: 1300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1300.png
#
# row: 200  col: 1350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1350.png
#
# row: 200  col: 1400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1400.png
#
# row: 200  col: 1450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1450.png
#
# row: 200  col: 1500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1500.png
#
# row: 200  col: 1550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1550.png
#
# row: 200  col: 1600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1600.png
#
# row: 200  col: 1650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1650.png
#
# row: 200  col: 1700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1700.png
#
# row: 200  col: 1750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1750.png
#
# row: 200  col: 1800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1800.png
#
# row: 200  col: 1850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1850.png
#
# row: 200  col: 1900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1900.png
#
# row: 200  col: 1950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j1950.png
#
# row: 200  col: 2000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2000.png
#
# row: 200  col: 2050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2050.png
#
# row: 200  col: 2100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2100.png
#
# row: 200  col: 2150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2150.png
#
# row: 200  col: 2200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2200.png
#
# row: 200  col: 2250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2250.png
#
# row: 200  col: 2300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2300.png
#
# row: 200  col: 2350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2350.png
#
# row: 200  col: 2400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2400.png
#
# row: 200  col: 2450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2450.png
#
# row: 200  col: 2500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2500.png
#
# row: 200  col: 2550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2550.png
#
# row: 200  col: 2600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2600.png
#
# row: 200  col: 2650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2650.png
#
# row: 200  col: 2700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2700.png
#
# row: 200  col: 2750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2750.png
#
# row: 200  col: 2800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2800.png
#
# row: 200  col: 2850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2850.png
#
# row: 200  col: 2900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2900.png
#
# row: 200  col: 2950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j2950.png
#
# row: 200  col: 3000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j3000.png
#
# row: 200  col: 3050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j3050.png
#
# row: 200  col: 3100 	 numpy_sum: 2263
# Evaluate score:= 6.06786441803
# test/ImgWithPatch_i200_j3100.png
#
# row: 200  col: 3150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i200_j3150.png
#
# row: 200  col: 3200 	 numpy_sum: 1450
# Evaluate score:= 2.70778274536
# test/ImgWithPatch_i200_j3200.png
#
# row: 250  col: 0 	 numpy_sum: 1776
# Evaluate score:= 0.82874661684
# test/ImgWithPatch_i250_j0.png
#
# row: 250  col: 50 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j50.png
#
# row: 250  col: 100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j100.png
#
# row: 250  col: 150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j150.png
#
# row: 250  col: 200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j200.png
#
# row: 250  col: 250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j250.png
#
# row: 250  col: 300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j300.png
#
# row: 250  col: 350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j350.png
#
# row: 250  col: 400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j400.png
#
# row: 250  col: 450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j450.png
# row: 250  col: 500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j500.png
#
# row: 250  col: 550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j550.png
#
# row: 250  col: 600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j600.png
#
# row: 250  col: 650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j650.png
#
# row: 250  col: 700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j700.png
#
# row: 250  col: 750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j750.png
#
# row: 250  col: 800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j800.png
#
# row: 250  col: 850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j850.png
#
# row: 250  col: 900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j900.png
#
# row: 250  col: 950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j950.png
#
# row: 250  col: 1000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1000.png
#
# row: 250  col: 1050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1050.png
#
# row: 250  col: 1100 	 numpy_sum: 2465
# Evaluate score:= 1.08997285366
# test/ImgWithPatch_i250_j1100.png
#
# row: 250  col: 1150 	 numpy_sum: 2479
# Evaluate score:= 1.34230923653
# test/ImgWithPatch_i250_j1150.png
#
# row: 250  col: 1200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1200.png
#
# row: 250  col: 1250 	 numpy_sum: 2462
# Evaluate score:= 1.4244954586
# test/ImgWithPatch_i250_j1250.png
#
# row: 250  col: 1300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1300.png
#
# row: 250  col: 1350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1350.png
#
# row: 250  col: 1400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1400.png
#
# row: 250  col: 1450 	 numpy_sum: 2485
# Evaluate score:= 1.15096652508
# test/ImgWithPatch_i250_j1450.png
#
# row: 250  col: 1500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1500.png
#
# row: 250  col: 1550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1550.png
#
# row: 250  col: 1600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1600.png
#
# row: 250  col: 1650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1650.png
#
# row: 250  col: 1700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1700.png
#
# row: 250  col: 1750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1750.png
#
# row: 250  col: 1800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1800.png
#
# row: 250  col: 1850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1850.png
#
# row: 250  col: 1900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1900.png
#
# row: 250  col: 1950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j1950.png
#
# row: 250  col: 2000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2000.png
#
# row: 250  col: 2050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2050.png
#
# row: 250  col: 2100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2100.png
#
# row: 250  col: 2150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2150.png
#
# row: 250  col: 2200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2200.png
#
# row: 250  col: 2250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2250.png
#
# row: 250  col: 2300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2300.png
#
# row: 250  col: 2350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2350.png
#
# row: 250  col: 2400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2400.png
#
# row: 250  col: 2450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2450.png
#
# row: 250  col: 2500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2500.png
#
# row: 250  col: 2550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2550.png
#
# row: 250  col: 2600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2600.png
#
# row: 250  col: 2650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2650.png
#
# row: 250  col: 2700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2700.png
#
# row: 250  col: 2750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2750.png
#
# row: 250  col: 2800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2800.png
#
# row: 250  col: 2850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2850.png
#
# row: 250  col: 2900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2900.png
#
# row: 250  col: 2950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j2950.png
#
# row: 250  col: 3000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j3000.png
#
# row: 250  col: 3050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j3050.png
#
# row: 250  col: 3100 	 numpy_sum: 2279
# Evaluate score:= 7.07531356812
# test/ImgWithPatch_i250_j3100.png
#
# row: 250  col: 3150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i250_j3150.png
#
# row: 250  col: 3200 	 numpy_sum: 1450
# Evaluate score:= 2.70778274536
# test/ImgWithPatch_i250_j3200.png
#
# row: 300  col: 0 	 numpy_sum: 1795
# Evaluate score:= 1.54063642025
# test/ImgWithPatch_i300_j0.png
#
# row: 300  col: 50 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j50.png
#
# row: 300  col: 100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j100.png
#
# row: 300  col: 150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j150.png
#
# row: 300  col: 200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j200.png
#
# row: 300  col: 250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j250.png
#
# row: 300  col: 300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j300.png
#
# row: 300  col: 350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j350.png
#
# row: 300  col: 400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j400.png
#
# row: 300  col: 450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j450.png
#
# row: 300  col: 500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j500.png
#
# row: 300  col: 550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j550.png
#
# row: 300  col: 600 	 numpy_sum: 2482
# Evaluate score:= 1.3936612606
# test/ImgWithPatch_i300_j600.png
#
# row: 300  col: 650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j650.png
#
# row: 300  col: 700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j700.png
#
# row: 300  col: 750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j750.png
#
# row: 300  col: 800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j800.png
#
# row: 300  col: 850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j850.png
#
# row: 300  col: 900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j900.png
#
# row: 300  col: 950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j950.png
#
# row: 300  col: 1000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1000.png
#
# row: 300  col: 1050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1050.png
#
# row: 300  col: 1100 	 numpy_sum: 2494
# Evaluate score:= 0.870038151741
# test/ImgWithPatch_i300_j1100.png
#
# row: 300  col: 1150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1150.png
#
# row: 300  col: 1200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1200.png
#
# row: 300  col: 1250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1250.png
#
# row: 300  col: 1300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1300.png
#
# row: 300  col: 1350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1350.png
#
# row: 300  col: 1400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1400.png
#
# row: 300  col: 1450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1450.png
#
# row: 300  col: 1500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1500.png
# row: 300  col: 1550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1550.png
#
# row: 300  col: 1600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1600.png
#
# row: 300  col: 1650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1650.png
#
# row: 300  col: 1700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1700.png
#
# row: 300  col: 1750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1750.png
#
# row: 300  col: 1800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1800.png
#
# row: 300  col: 1850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1850.png
#
# row: 300  col: 1900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j1900.png
#
# row: 300  col: 1950 	 numpy_sum: 2486
# Evaluate score:= 1.1982023716
# test/ImgWithPatch_i300_j1950.png
#
# row: 300  col: 2000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2000.png
#
# row: 300  col: 2050 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2050.png
#
# row: 300  col: 2100 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2100.png
#
# row: 300  col: 2150 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2150.png
#
# row: 300  col: 2200 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2200.png
#
# row: 300  col: 2250 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2250.png
#
# row: 300  col: 2300 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2300.png
#
# row: 300  col: 2350 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2350.png
#
# row: 300  col: 2400 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2400.png
#
# row: 300  col: 2450 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2450.png
#
# row: 300  col: 2500 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2500.png
#
# row: 300  col: 2550 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2550.png
#
# row: 300  col: 2600 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2600.png
#
# row: 300  col: 2650 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2650.png
#
# row: 300  col: 2700 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2700.png
#
# row: 300  col: 2750 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2750.png
#
# row: 300  col: 2800 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2800.png
#
# row: 300  col: 2850 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2850.png
#
# row: 300  col: 2900 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2900.png
#
# row: 300  col: 2950 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j2950.png
#
# row: 300  col: 3000 	 numpy_sum: 2500
# Evaluate score:= 1.1943218708
# test/ImgWithPatch_i300_j3000.png
